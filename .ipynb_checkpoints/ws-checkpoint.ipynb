# %%
from bs4 import BeautifulSoup
import os

# %%
import requests

# %%
print("hello")
# Out:
# hello

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
# ...
driver.get("https://www.instagram.com/p/C3YlU5LPrDm/")
driver.maximize_window()

print(driver.title)
driver.quit()
# Out:
# Rachel Cruze on Instagram: "23% of singles say that being frugal is a quality they look for in a partner. Whether you are pursuing a new relationship or you have been married for years, make sure you are budgeting for dates — and don’t be afraid to balance out nice meals with things like walks… What are some budget friendly date ideas y’all enjoy?"
